# %%
import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.optimizers import SGD
from keras.utils import to_categorical
import numpy as np

import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32') / 255
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32') / 255

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
SHIFT_FACTOR = tf.exp(2.0)
SCALE_FACTOR = 6.5
TOP_SCALE = 2.0
def bottom_sig(x):
    return SCALE_FACTOR/(1+tf.exp(-(2*x+SHIFT_FACTOR))) - SCALE_FACTOR
def bottom_sig_relu(x):
    return -(x+SCALE_FACTOR)**TOP_SCALE-SCALE_FACTOR
def top_sig(x):
    return SCALE_FACTOR/(1+tf.exp(-(2*x-SHIFT_FACTOR)))
def top_sig_relu(x):
    return (x-SCALE_FACTOR)**TOP_SCALE+SCALE_FACTOR
def three_sigmoid_activation(x):
    return tf.where(x < -0, bottom_sig(x), tf.where(x >= 0, top_sig(x), x))

def three_sig_relu_activation(x):
    return tf.where(x < -SCALE_FACTOR, bottom_sig_relu(x), tf.where(x > SCALE_FACTOR, top_sig_relu(x), three_sigmoid_activation(x)))
# Out:
# 2024-10-17 22:41:22.778624: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Ultra
# 2024-10-17 22:41:22.778643: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 128.00 GB
# 2024-10-17 22:41:22.778648: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 48.00 GB
# 2024-10-17 22:41:22.778662: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-17 22:41:22.778673: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Functional API Experimentation

# %%
model = Sequential([
    Conv2D(16, (3, 3), activation='sigmoid', input_shape=(28, 28, 1)),  # 16 filters (reduced), 3x3 kernel
    MaxPooling2D(pool_size=(5, 5)),  # Max pooling with 2x2 pool size
    # Flatten the output before passing to Dense layers
    Flatten(),
    Dense(64, activation='softmax'),  # Reduced from 128 to 64 units
    Dense(10, activation='softmax')  # Output layer with 10 units for classification
])

learning_rate = 0.002
epochs = 1
batch_size = 48

# Compile the model
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print('Test accuracy:', accuracy)
# Out:
# /Users/thomasjones/.pyenv/versions/3.10.15/envs/MLExp/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-10-17 22:41:23.808142: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.2356 - loss: 1.9328
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3374 - loss: 1.4441
# Test accuracy: 0.33309999108314514

# %%
epochs = 50

image_inputs_source = keras.Input(shape=(28, 28, 1))

image_inputs = keras.layers.Dropout(0.25)(image_inputs_source)

conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(image_inputs)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
conv11 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
flat1 = Flatten()(pool11)

conv2 = Conv2D(32, (4, 4), activation='relu', padding='same')(image_inputs)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
conv22 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
pool22 = MaxPooling2D(pool_size=(2, 2))(conv22)
flat2 = Flatten()(pool22)

conv3 = Conv2D(32, (5, 5), activation='relu', padding='same')(image_inputs)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
conv33 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool3)
pool33 = MaxPooling2D(pool_size=(2, 2))(conv33)
flat3 = Flatten()(pool33)

conv4 = Conv2D(32, (6, 6), activation='relu', padding='same')(image_inputs)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
conv44 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool4)
pool44 = MaxPooling2D(pool_size=(2, 2))(conv44)
flat4 = Flatten()(pool44)

conv5 = Conv2D(32, (7, 7), activation='relu', padding='same')(image_inputs)
pool5 = MaxPooling2D(pool_size=(2, 2))(conv5)
conv55 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool5)
pool55 = MaxPooling2D(pool_size=(2, 2))(conv55)
flat5 = Flatten()(pool55)

convhalf = Conv2D(32, (14, 14), activation='relu', padding='same')(image_inputs)
poolhalf = MaxPooling2D(pool_size=(2, 2))(convhalf)
convhalf2 = Conv2D(128, (3, 3), activation='relu', padding='same')(poolhalf)
poolhalf2 = MaxPooling2D(pool_size=(2, 2))(convhalf2)
flathalf = Flatten()(convhalf2)


concat_first_conv = keras.layers.concatenate([conv1, conv2, conv3, conv4, conv5, convhalf])
flatten_first_conv = Flatten()(concat_first_conv)

concat_input = keras.layers.concatenate([flat1, flat2, flat3, flat4, flat5, flathalf, flatten_first_conv])
dropout = keras.layers.Dropout(0.1)(concat_input)
dense2 = Dense(64, activation='sigmoid')(dropout)
dense3 = Dense(64, activation='relu')(dense2)
output2 = Dense(10, activation='softmax')(dense3)

model = keras.Model(inputs=image_inputs, outputs=output2)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=keras.optimizers.schedules.ExponentialDecay(learning_rate, decay_steps=10000, decay_rate=0.999, staircase=True)),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1, validation_data=(x_test, y_test))
loss, accuracy = model.evaluate(x_test, y_test)
print('Test accuracy:', accuracy)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ keras_tensor_84CLO… │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 28, 28,    │        320 │ keras_tensor_84C… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 28, 28,    │        544 │ keras_tensor_84C… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 28, 28,    │        832 │ keras_tensor_84C… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 28, 28,    │      1,184 │ keras_tensor_84C… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 28, 28,    │      1,600 │ keras_tensor_84C… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_25    │ (None, 14, 14,    │          0 │ conv2d_25[1][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_27    │ (None, 14, 14,    │          0 │ conv2d_27[1][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_29    │ (None, 14, 14,    │          0 │ conv2d_29[1][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_31    │ (None, 14, 14,    │          0 │ conv2d_31[1][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_33    │ (None, 14, 14,    │          0 │ conv2d_33[1][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 28, 28,    │      6,304 │ keras_tensor_84C… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 14, 14,    │     36,992 │ max_pooling2d_25… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 14, 14,    │     36,992 │ max_pooling2d_27… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 14, 14,    │     36,992 │ max_pooling2d_29… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 14, 14,    │     36,992 │ max_pooling2d_31… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 14, 14,    │     36,992 │ max_pooling2d_33… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_35    │ (None, 14, 14,    │          0 │ conv2d_35[1][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_26    │ (None, 7, 7, 128) │          0 │ conv2d_26[1][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_28    │ (None, 7, 7, 128) │          0 │ conv2d_28[1][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_30    │ (None, 7, 7, 128) │          0 │ conv2d_30[1][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_32    │ (None, 7, 7, 128) │          0 │ conv2d_32[1][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_34    │ (None, 7, 7, 128) │          0 │ conv2d_34[1][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 14, 14,    │     36,992 │ max_pooling2d_35… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 28, 28,    │          0 │ conv2d_25[1][0],  │
# │ (Concatenate)       │ 192)              │            │ conv2d_27[1][0],  │
# │                     │                   │            │ conv2d_29[1][0],  │
# │                     │                   │            │ conv2d_31[1][0],  │
# │                     │                   │            │ conv2d_33[1][0],  │
# │                     │                   │            │ conv2d_35[1][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_15          │ (None, 6272)      │          0 │ max_pooling2d_26… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_16          │ (None, 6272)      │          0 │ max_pooling2d_28… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_17          │ (None, 6272)      │          0 │ max_pooling2d_30… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_18          │ (None, 6272)      │          0 │ max_pooling2d_32… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_19          │ (None, 6272)      │          0 │ max_pooling2d_34… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_20          │ (None, 25088)     │          0 │ conv2d_36[1][0]   │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_21          │ (None, 150528)    │          0 │ concatenate_4[1]… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 206976)    │          0 │ flatten_15[1][0], │
# │ (Concatenate)       │                   │            │ flatten_16[1][0], │
# │                     │                   │            │ flatten_17[1][0], │
# │                     │                   │            │ flatten_18[1][0], │
# │                     │                   │            │ flatten_19[1][0], │
# │                     │                   │            │ flatten_20[1][0], │
# │                     │                   │            │ flatten_21[1][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 206976)    │          0 │ concatenate_5[1]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64)        │ 13,246,528 │ dropout_4[1][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │      4,160 │ dense_8[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 10)        │        650 │ dense_9[1][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,484,074 (51.44 MB)
#  Trainable params: 13,484,074 (51.44 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 66s 50ms/step - accuracy: 0.7954 - loss: 0.6097 - val_accuracy: 0.8850 - val_loss: 0.3148
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9114 - loss: 0.2418 - val_accuracy: 0.8968 - val_loss: 0.2921
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9296 - loss: 0.1904 - val_accuracy: 0.9023 - val_loss: 0.2738
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9451 - loss: 0.1519 - val_accuracy: 0.9062 - val_loss: 0.2755
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.9545 - loss: 0.1251 - val_accuracy: 0.9139 - val_loss: 0.2648
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - accuracy: 0.9638 - loss: 0.0994 - val_accuracy: 0.9067 - val_loss: 0.3041
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.9720 - loss: 0.0797 - val_accuracy: 0.9078 - val_loss: 0.3169
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - accuracy: 0.9764 - loss: 0.0657 - val_accuracy: 0.9062 - val_loss: 0.3451
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.9797 - loss: 0.0558 - val_accuracy: 0.9085 - val_loss: 0.3647
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 51ms/step - accuracy: 0.9828 - loss: 0.0474 - val_accuracy: 0.9128 - val_loss: 0.3542
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.9881 - loss: 0.0346 - val_accuracy: 0.9143 - val_loss: 0.3675
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.9869 - loss: 0.0384 - val_accuracy: 0.9045 - val_loss: 0.4234
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.9872 - loss: 0.0371 - val_accuracy: 0.9087 - val_loss: 0.4354
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.9901 - loss: 0.0284 - val_accuracy: 0.9134 - val_loss: 0.4556
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.9901 - loss: 0.0253 - val_accuracy: 0.9097 - val_loss: 0.4545
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.9919 - loss: 0.0233 - val_accuracy: 0.9055 - val_loss: 0.4936
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 51ms/step - accuracy: 0.9918 - loss: 0.0234 - val_accuracy: 0.9087 - val_loss: 0.4552
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.9928 - loss: 0.0211 - val_accuracy: 0.9077 - val_loss: 0.5359
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.9918 - loss: 0.0247 - val_accuracy: 0.9053 - val_loss: 0.5239
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.9928 - loss: 0.0204 - val_accuracy: 0.9058 - val_loss: 0.5413
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.9923 - loss: 0.0218 - val_accuracy: 0.9048 - val_loss: 0.5431
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - accuracy: 0.9918 - loss: 0.0234 - val_accuracy: 0.9064 - val_loss: 0.5572
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - accuracy: 0.9940 - loss: 0.0169 - val_accuracy: 0.9093 - val_loss: 0.5712
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - accuracy: 0.9936 - loss: 0.0184 - val_accuracy: 0.9083 - val_loss: 0.5613
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - accuracy: 0.9941 - loss: 0.0173 - val_accuracy: 0.9084 - val_loss: 0.5444
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - accuracy: 0.9943 - loss: 0.0156 - val_accuracy: 0.9032 - val_loss: 0.5635
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9934 - loss: 0.0169 - val_accuracy: 0.9058 - val_loss: 0.5678
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9954 - loss: 0.0128 - val_accuracy: 0.9069 - val_loss: 0.5948
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9934 - loss: 0.0183 - val_accuracy: 0.9068 - val_loss: 0.5788
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9953 - loss: 0.0139 - val_accuracy: 0.9076 - val_loss: 0.5992
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9941 - loss: 0.0163 - val_accuracy: 0.9033 - val_loss: 0.6058
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9958 - loss: 0.0130 - val_accuracy: 0.9057 - val_loss: 0.6248
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9941 - loss: 0.0166 - val_accuracy: 0.9069 - val_loss: 0.6015
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9949 - loss: 0.0140 - val_accuracy: 0.9077 - val_loss: 0.5702
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9950 - loss: 0.0143 - val_accuracy: 0.9067 - val_loss: 0.6091
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9948 - loss: 0.0146 - val_accuracy: 0.9101 - val_loss: 0.5764
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9958 - loss: 0.0116 - val_accuracy: 0.9067 - val_loss: 0.6160
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9937 - loss: 0.0181 - val_accuracy: 0.9079 - val_loss: 0.6305
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9953 - loss: 0.0132 - val_accuracy: 0.9031 - val_loss: 0.6586
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9949 - loss: 0.0153 - val_accuracy: 0.9061 - val_loss: 0.6289
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9970 - loss: 0.0096 - val_accuracy: 0.9091 - val_loss: 0.5884
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 62s 50ms/step - accuracy: 0.9959 - loss: 0.0126 - val_accuracy: 0.9089 - val_loss: 0.6094
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.9960 - loss: 0.0122 - val_accuracy: 0.9062 - val_loss: 0.6543
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.9943 - loss: 0.0157 - val_accuracy: 0.9026 - val_loss: 0.6832
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9949 - loss: 0.0149 - val_accuracy: 0.9085 - val_loss: 0.6320
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9968 - loss: 0.0091 - val_accuracy: 0.9054 - val_loss: 0.6643
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9959 - loss: 0.0121 - val_accuracy: 0.9055 - val_loss: 0.6720
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9969 - loss: 0.0091 - val_accuracy: 0.9059 - val_loss: 0.6515
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9960 - loss: 0.0114 - val_accuracy: 0.9090 - val_loss: 0.6630
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.9957 - loss: 0.0125 - val_accuracy: 0.9078 - val_loss: 0.6642
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9060 - loss: 0.6699
# Test accuracy: 0.907800018787384
